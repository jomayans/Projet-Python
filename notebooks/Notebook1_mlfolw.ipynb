# %%
import mlflow

# %%
mlflow_experiment='Box_office_prediction'
mlflow.set_experiment(experiment_name=mlflow_experiment)
# Out:
# 2024/04/29 12:28:10 INFO mlflow.tracking.fluent: Experiment with name 'Box_office_prediction' does not exist. Creating a new experiment.
# <Experiment: artifact_location='mlflow-artifacts:/2', creation_time=1714393690100, experiment_id='2', last_update_time=1714393690100, lifecycle_stage='active', name='Box_office_prediction', tags={}>

# %%
from sklearn.model_selection import ParameterGrid



def get_hyperparameter_combinations(parameters):
        
        return list(ParameterGrid(parameters))

# %%
get_hyperparameter_combinations(parameters)
# Out:
# [{'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 5,
#   'min_child_weight': 3,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 5,
#   'min_child_weight': 3,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 5,
#   'min_child_weight': 3,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 5,
#   'min_child_weight': 3,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 5,
#   'min_child_weight': 3,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 5,
#   'min_child_weight': 3,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 5,
#   'min_child_weight': 3,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 5,
#   'min_child_weight': 3,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 5,
#   'min_child_weight': 3,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 5,
#   'min_child_weight': 4,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 5,
#   'min_child_weight': 4,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 5,
#   'min_child_weight': 4,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 5,
#   'min_child_weight': 4,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 5,
#   'min_child_weight': 4,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 5,
#   'min_child_weight': 4,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 5,
#   'min_child_weight': 4,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 5,
#   'min_child_weight': 4,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 5,
#   'min_child_weight': 4,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 6,
#   'min_child_weight': 3,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 6,
#   'min_child_weight': 3,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 6,
#   'min_child_weight': 3,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 6,
#   'min_child_weight': 3,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 6,
#   'min_child_weight': 3,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 6,
#   'min_child_weight': 3,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 6,
#   'min_child_weight': 3,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 6,
#   'min_child_weight': 3,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 6,
#   'min_child_weight': 3,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 6,
#   'min_child_weight': 4,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 6,
#   'min_child_weight': 4,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 6,
#   'min_child_weight': 4,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 6,
#   'min_child_weight': 4,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 6,
#   'min_child_weight': 4,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 6,
#   'min_child_weight': 4,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 6,
#   'min_child_weight': 4,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 6,
#   'min_child_weight': 4,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 6,
#   'min_child_weight': 4,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 7,
#   'min_child_weight': 3,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 7,
#   'min_child_weight': 3,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 7,
#   'min_child_weight': 3,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 7,
#   'min_child_weight': 3,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 7,
#   'min_child_weight': 3,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 7,
#   'min_child_weight': 3,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 7,
#   'min_child_weight': 3,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 7,
#   'min_child_weight': 3,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 7,
#   'min_child_weight': 3,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 7,
#   'min_child_weight': 4,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 7,
#   'min_child_weight': 4,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 7,
#   'min_child_weight': 4,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 7,
#   'min_child_weight': 4,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 7,
#   'min_child_weight': 4,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 7,
#   'min_child_weight': 4,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 7,
#   'min_child_weight': 4,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 7,
#   'min_child_weight': 4,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 7,
#   'min_child_weight': 4,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 5,
#   'min_child_weight': 3,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 5,
#   'min_child_weight': 3,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 5,
#   'min_child_weight': 3,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 5,
#   'min_child_weight': 3,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 5,
#   'min_child_weight': 3,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 5,
#   'min_child_weight': 3,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 5,
#   'min_child_weight': 3,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 5,
#   'min_child_weight': 3,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 5,
#   'min_child_weight': 3,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 5,
#   'min_child_weight': 4,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 5,
#   'min_child_weight': 4,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 5,
#   'min_child_weight': 4,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 5,
#   'min_child_weight': 4,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 5,
#   'min_child_weight': 4,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 5,
#   'min_child_weight': 4,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 5,
#   'min_child_weight': 4,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 5,
#   'min_child_weight': 4,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 5,
#   'min_child_weight': 4,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 6,
#   'min_child_weight': 3,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 6,
#   'min_child_weight': 3,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 6,
#   'min_child_weight': 3,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 6,
#   'min_child_weight': 3,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 6,
#   'min_child_weight': 3,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 6,
#   'min_child_weight': 3,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 6,
#   'min_child_weight': 3,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 6,
#   'min_child_weight': 3,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 6,
#   'min_child_weight': 3,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 6,
#   'min_child_weight': 4,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 6,
#   'min_child_weight': 4,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 6,
#   'min_child_weight': 4,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 6,
#   'min_child_weight': 4,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 6,
#   'min_child_weight': 4,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 6,
#   'min_child_weight': 4,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 6,
#   'min_child_weight': 4,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 6,
#   'min_child_weight': 4,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 6,
#   'min_child_weight': 4,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 7,
#   'min_child_weight': 3,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 7,
#   'min_child_weight': 3,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 7,
#   'min_child_weight': 3,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 7,
#   'min_child_weight': 3,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 7,
#   'min_child_weight': 3,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 7,
#   'min_child_weight': 3,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 7,
#   'min_child_weight': 3,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 7,
#   'min_child_weight': 3,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 7,
#   'min_child_weight': 3,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 7,
#   'min_child_weight': 4,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 7,
#   'min_child_weight': 4,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 7,
#   'min_child_weight': 4,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 7,
#   'min_child_weight': 4,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 7,
#   'min_child_weight': 4,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 7,
#   'min_child_weight': 4,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 7,
#   'min_child_weight': 4,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 7,
#   'min_child_weight': 4,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'max_depth': 7,
#   'min_child_weight': 4,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 5,
#   'min_child_weight': 3,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 5,
#   'min_child_weight': 3,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 5,
#   'min_child_weight': 3,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 5,
#   'min_child_weight': 3,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 5,
#   'min_child_weight': 3,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 5,
#   'min_child_weight': 3,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 5,
#   'min_child_weight': 3,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 5,
#   'min_child_weight': 3,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 5,
#   'min_child_weight': 3,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 5,
#   'min_child_weight': 4,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 5,
#   'min_child_weight': 4,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 5,
#   'min_child_weight': 4,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 5,
#   'min_child_weight': 4,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 5,
#   'min_child_weight': 4,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 5,
#   'min_child_weight': 4,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 5,
#   'min_child_weight': 4,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 5,
#   'min_child_weight': 4,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 5,
#   'min_child_weight': 4,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 6,
#   'min_child_weight': 3,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 6,
#   'min_child_weight': 3,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 6,
#   'min_child_weight': 3,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 6,
#   'min_child_weight': 3,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 6,
#   'min_child_weight': 3,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 6,
#   'min_child_weight': 3,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 6,
#   'min_child_weight': 3,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 6,
#   'min_child_weight': 3,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 6,
#   'min_child_weight': 3,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 6,
#   'min_child_weight': 4,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 6,
#   'min_child_weight': 4,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 6,
#   'min_child_weight': 4,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 6,
#   'min_child_weight': 4,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 6,
#   'min_child_weight': 4,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 6,
#   'min_child_weight': 4,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 6,
#   'min_child_weight': 4,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 6,
#   'min_child_weight': 4,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 6,
#   'min_child_weight': 4,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 7,
#   'min_child_weight': 3,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 7,
#   'min_child_weight': 3,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 7,
#   'min_child_weight': 3,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 7,
#   'min_child_weight': 3,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 7,
#   'min_child_weight': 3,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 7,
#   'min_child_weight': 3,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 7,
#   'min_child_weight': 3,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 7,
#   'min_child_weight': 3,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 7,
#   'min_child_weight': 3,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 7,
#   'min_child_weight': 4,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 7,
#   'min_child_weight': 4,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 7,
#   'min_child_weight': 4,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 7,
#   'min_child_weight': 4,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 7,
#   'min_child_weight': 4,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 7,
#   'min_child_weight': 4,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 7,
#   'min_child_weight': 4,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 7,
#   'min_child_weight': 4,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.07,
#   'max_depth': 7,
#   'min_child_weight': 4,
#   'n_estimators': 2800,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9}]

# %%
import sys
sys.path.append('/home/onyxia/work/cine-insights/src/models')
sys.path.append('/home/onyxia/work/cine-insights/src/data')
sys.path.append('/home/onyxia/work/cine-insights/src/features')
sys.path.append('/home/onyxia/work/cine-insights/src/models')

sys.path.append('/home/onyxia/work/cine-insights/models')

# %%
import pandas as pd
import numpy as np

# %%
a=np.zeros((3,2))
a=pd.DataFrame(a,columns=["a","b"])
a.values
# Out:
# array([[0., 0.],
#        [0., 0.],
#        [0., 0.]])
