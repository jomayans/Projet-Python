# %%
import warnings

# Ignorer tous les avertissements
warnings.filterwarnings("ignore")

# %%
import sys
sys.path.append('/home/onyxia/work/cine-insights/src/features')
sys.path.append('/home/onyxia/work/cine-insights/src/models')
import pandas as pd
import joblib

# %%
import Build_Feats1a
# Utilisez les fonctions du module file
from  Build_Feats1a import *

import Predict_model_t


# Utilisez les fonctions du module file
from  Predict_model_t import *
import Build10

# Utilisez les fonctions du module file

# Utilisez les fonctions du module file
from aaa1 import *
from Build10 import *
import Train_madel101


# Utilisez les fonctions du module file
from Train_madel101 import *
import Train_model_xgboot


# Utilisez les fonctions du module file
from  Train_model_xgboot import *

# %%
(X,y),_,_ =preprocessing_data(df)
# Out:
# (x.shape, y.shape )
#
#  Pour le train : (37, 24) (37,)
#
#  Pour le test : (11, 24) (11,)
#
#  Pour la validation : (2, 24) (2,)

# %%
Scaler_DEScaler_X=Scaler_DEScaler()
X_norm=Scaler_DEScaler_X.normalizer(X)
X_norm.head(2)
# Out:
#      budget  popularity  ...  Keywords_count  released
# 8  0.796773    0.062820  ...        0.076923       0.0
# 3  0.885145    0.538338  ...        0.538462       0.0
#
# [2 rows x 24 columns]

# %% [markdown]
# # Test Model.py

# %%
X_norm.shape,y.shape
# Out:
# ((37, 24), (37,))

# %%
show_models_performances(X_norm,y,X_norm,y)
# Out:
#             ExpID   Train RMSLE  ...  Train Time(s)  Experiment description
# 1  Initial Search  3.626129e+08  ...         0.0064          Untuned linear
#
# [1 rows x 6 columns]
#             ExpID   Train RMSLE  ...  Train Time(s)  Experiment description
# 1  Initial Search  3.626129e+08  ...         0.0064          Untuned linear
# 2  Initial Search  4.872330e+08  ...         0.0246              Untuned kn
#
# [2 rows x 6 columns]

# %% [markdown]
#  # Train_model.py

# %%
df=pd.read_csv("Raw_df_50_ligne.csv")
df.head(2)
# Out:
#    Unnamed: 0      id         title  vote_average  vote_count    status  \
# 0           0   27205     Inception         8.364       34495  Released
# 1           1  157336  Interstellar         8.417       32571  Released
#
#   release_date    revenue  runtime  adult  ... original_title  \
# 0   2010-07-15  825532764      148  False  ...      Inception
# 1   2014-11-05  701729206      169  False  ...   Interstellar
#
#                                             overview popularity  \
# 0  Cobb, a skilled thief who commits corporate es...     83.952
# 1  The adventures of a group of explorers who mak...    140.241
#
#                         poster_path  \
# 0  /oYuLEt3zVCKq57qu2F8dT7NIa6f.jpg
# 1  /gEU2QniE6E77NI6lCU6MxlNBvIx.jpg
#
#                                              tagline  \
# 0               Your mind is the scene of the crime.
# 1  Mankind was born on Earth. It was never meant ...
#
#                                genres  \
# 0  Action, Science Fiction, Adventure
# ...

# %%
(x_train,y_train),(x_test,y_test),(x_val,y_val)=get_clean_df(df)
# Out:
# (x.shape, y.shape )
#
#  Pour le train : (37, 24) (37,)
#
#  Pour le test : (11, 24) (11,)
#
#  Pour la validation : (2, 24) (2,)

# %%
Lin_Reg_Trainer=XGBRegressorWrapper(x_train,y_train,x_test,y_test)
Lin_Reg_Trainer._train_model()
# Out:
# Fitting 2 folds for each of 162 candidates, totalling 324 fits
# /home/onyxia/work/cine-insights/src/BOF_Virtual_ENv/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [01:16:33] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/onyxia/work/cine-insights/src/BOF_Virtual_ENv/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [01:16:33] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/onyxia/work/cine-insights/src/BOF_Virtual_ENv/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [01:16:33] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/onyxia/work/cine-insights/src/BOF_Virtual_ENv/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [01:16:33] WARNING: /workspace/src/learner.cc:742:
# ...

# %%
Lin_Reg_Trainer.display_results()
# Out:
#                                      Best parameters  Training RMSLE  \
# 0  {'colsample_bytree': 0.7, 'learning_rate': 0.0...       -0.135773
#
#                                           Test RMSLE  Test MAPE  Training time
# 0  4                            NaN
# 12           ...  63.959912         2.1208

# %%
Lin_Reg_Trainer.save_best_model("best_model.pkl")
# Out:
#                      Message
# 0  Model saved successfully.

# %%
Lin_Reg_Trainer.predict_(X_transformed)
# Out:
# array([ 8.2606003e+08,  7.0128000e+08,  1.0034585e+09,  2.9219246e+09,
#         3.9323590e+08,  7.8083418e+08,  2.0670292e+09,  1.0074989e+08,
#         7.7229888e+08,  2.1500736e+08,  6.8148115e+08,  9.7090835e+08,
#        -8.2002300e+06,  7.3667725e+08,  2.7141142e+07,  2.7779533e+09,
#         4.6325539e+08,  5.5021107e+08,  1.0788904e+09,  9.4342278e+08,
#         1.1169192e+09,  2.9485494e+08,  3.9242864e+08,  1.4081034e+09,
#         1.1608521e+09,  2.0927644e+09,  6.0186451e+08,  1.3513350e+09,
#         6.7648506e+08,  3.8070637e+08,  7.6994624e+08,  6.9454822e+08,
#         7.8334125e+08,  8.7931878e+08,  8.6123008e+08,  9.2691136e+08,
#         3.7269955e+08,  9.3637875e+08,  7.8851904e+08,  6.3474010e+08,
#         6.2656070e+08,  3.7484736e+08,  8.5552499e+08,  8.5585082e+08,
#         1.6702816e+09,  7.0603712e+08,  8.9717466e+08,  6.5629478e+08,
#         5.3463862e+08,  7.7575206e+08], dtype=float32)

# %%
loaded_model = joblib.load("best_model.pkl")
predictions = Predictor.predict(loaded_model, X_test)

# %% [markdown]
# # Build_feats1

# %%
df=pd.read_csv("Raw_df_50_ligne.csv")
X=df.drop(["revenue"],axis=1)
X.columns
# Out:
# Index(['Unnamed: 0', 'id', 'title', 'vote_average', 'vote_count', 'status',
#        'release_date', 'runtime', 'adult', 'backdrop_path', 'budget',
#        'homepage', 'imdb_id', 'original_language', 'original_title',
#        'overview', 'popularity', 'poster_path', 'tagline', 'genres',
#        'production_companies', 'production_countries', 'spoken_languages',
#        'Keywords'],
#       dtype='object')

# %%
X_transformed=Build_Feats1a.preprocessing_pipeline(X,ct)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/onyxia/work/cine-insights/src/data/test_preprocessing.ipynb Cell 20 line 8
#       <a href='vscode-notebook-cell://user-odione-468856-0.user.lab.sspcloud.fr/home/onyxia/work/cine-insights/src/data/test_preprocessing.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> # Utilisez les fonctions du module file
#       <a href='vscode-notebook-cell://user-odione-468856-0.user.lab.sspcloud.fr/home/onyxia/work/cine-insights/src/data/test_preprocessing.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> from  Build_Feats1a import *
# ----> <a href='vscode-notebook-cell://user-odione-468856-0.user.lab.sspcloud.fr/home/onyxia/work/cine-insights/src/data/test_preprocessing.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> X_transformed=Build_Feats1a.preprocessing_pipeline(X,ct)
#
# NameError: name 'ct' is not defined

# %%
X_transformed.columns
# Out:
# Index(['budget', 'popularity', 'has_homepage', 'release_month', 'release_year',
#        'genre_Action', 'genre_Adventure', 'genre_Animation', 'genre_Comedy',
#        'genre_Crime', 'genre_Drama', 'genre_Family', 'genre_Fantasy',
#        'genre_Mystery', 'genre_Romance', 'genre_Science_Fiction',
#        'genre_Thriller', 'genre_War', 'genre_Western',
#        'spoken_languages_count', 'production_countries_count',
#        'production_companies_count', 'Keywords_count', 'released'],
#       dtype='object')

# %% [markdown]
# # Test Predictor function

# %%
x_train.columns
# Out:
# Index(['budget', 'popularity', 'has_homepage', 'release_month', 'release_year',
#        'genre_Action', 'genre_Adventure', 'genre_Animation', 'genre_Comedy',
#        'genre_Crime', 'genre_Drama', 'genre_Family', 'genre_Fantasy',
#        'genre_Mystery', 'genre_Romance', 'genre_Science_Fiction',
#        'genre_Thriller', 'genre_War', 'genre_Western',
#        'spoken_languages_count', 'production_countries_count',
#        'production_companies_count', 'Keywords_count', 'released'],
#       dtype='object')

# %%
X.columns
# Out:
# Index(['Unnamed: 0', 'id', 'title', 'vote_average', 'vote_count', 'status',
#        'release_date', 'runtime', 'adult', 'backdrop_path', 'budget',
#        'homepage', 'imdb_id', 'original_language', 'original_title',
#        'overview', 'popularity', 'poster_path', 'tagline', 'genres',
#        'production_companies', 'production_countries', 'spoken_languages',
#        'Keywords'],
#       dtype='object')

# %%
#get trained model
loaded_model = joblib.load("best_model.pkl")
#definir une instance de la classe Predicto
Predictor=Predict_model_t.Predicto(loaded_model)
#appliquer la methode predict de cette class à X_test
predictions = Predictor.predict(X)

# %%
predictions
# Out:
# array([ 8.2606003e+08,  7.0128000e+08,  1.0034585e+09,  2.9219246e+09,
#         3.9323590e+08,  7.8083418e+08,  2.0670292e+09,  1.0074989e+08,
#         7.7229888e+08,  2.1500736e+08,  6.8148115e+08,  9.7090835e+08,
#        -8.2002300e+06,  7.3667725e+08,  2.7141142e+07,  2.7779533e+09,
#         4.6325539e+08,  5.5021107e+08,  1.0788904e+09,  9.4342278e+08,
#         1.1169192e+09,  2.9485494e+08,  3.9242864e+08,  1.4081034e+09,
#         1.1608521e+09,  2.0927644e+09,  6.0186451e+08,  1.3513350e+09,
#         6.7648506e+08,  3.8070637e+08,  7.6994624e+08,  6.9454822e+08,
#         7.8334125e+08,  8.7931878e+08,  8.6123008e+08,  9.2691136e+08,
#         3.7269955e+08,  9.3637875e+08,  7.8851904e+08,  6.3474010e+08,
#         6.2656070e+08,  3.7484736e+08,  8.5552499e+08,  8.5585082e+08,
#         1.6702816e+09,  7.0603712e+08,  8.9717466e+08,  6.5629478e+08,
#         5.3463862e+08,  7.7575206e+08], dtype=float32)

# %%
# Création de l'instance de la classe XGBRegressorWrapper
model = train_model_xgboot.XGBRegressorWrapper(X_train, y_train, X_test, y_test)

# Entraînement du modèle
model.train()

# Prédiction sur de nouvelles données
predictions = model.predict(X_new_data)

# %%
predictions = Predictor.predict(loaded_model, X_test)
