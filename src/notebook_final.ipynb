# %%
import src.main
# Out:
# /home/onyxia/work/cine-insights/src/features/preprocess_train_data.py:892: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   .groupby(level=0, axis=1)
# /home/onyxia/work/cine-insights/src/features/preprocess_train_data.py:736: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)
# ...

# %%
apiVersion: argoproj.io/v1alpha1
kind: Workflow
metadata:
  generateName: mlflow-training-
spec:
  schedule: "0 0 * * 0"  # Exécuter chaque dimanche à minuit
  entrypoint: mlflow-training
  arguments:
    parameters:
      - name: mlflow-tracking-uri
        value: https://user-odione-mlflow.user.lab.sspcloud.fr
      - name: mlflow-experiment-name
        value: Final Experiement 6
      - name: model-training-conf-list
        value: |
          [
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 6, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 6, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 6, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
          ]
  templates:
    - name: mlflow-training
      inputs:
        parameters:
          - name: objective
            value: ["reg:squarederror"]
          - name: learning_rates
            value: [0.03, 0.05, 0.07]
          - name: max_depths
            value: [5, 6, 7]
          - name: min_child_weights
            value: [3, 4]
          - name: subsamples
            value: [0.7, 0.8, 0.9]
          - name: colsample_bytrees
            value: [0.7]
          - name: n_estimators
            value: [500, 1000, 2800]
          # Ajout des paramètres de formation de modèle du premier fichier
          - name: model-training-conf-list
            value: |
              [
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.03, 'max_depths': 6, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 5, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 6, 'min_child_weights': 3, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 6, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 500},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 6, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 1000},
    {'objective': 'reg:squarederror', 'learning_rates': 0.05, 'max_depths': 6, 'min_child_weights': 4, 'subsamples': 0.7, 'colsample_bytrees': 0.7, 'n_estimators': 2800},
              ]
      script:
        image: yedson54/cine-insights:latest
        imagePullPolicy: Always
        command: ["/bin/bash", "-c"]
        source: |
          apt-get -y update && \
          apt-get install -y python3-pip && \
          pip install mlflow && \
          mkdir -p /home/cine_insights/src && \
          cp /src/main.py /home/cine_insights/src/main.py && \
          cd /home/cine_insights && \
          python3 main.py

# %%
import src.Mlflow_src.Fun_to_create_yaml_file3

# %%
import src.Mlflow

# %%
import src.Mlflow.mlflow_predict
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# /home/onyxia/work/cine-insights/src/notebook_final.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell://user-odione-952209-0.user.lab.sspcloud.fr/home/onyxia/work/cine-insights/src/notebook_final.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> import src.Mlflow.mlflow_predict
#
# File ~/work/cine-insights/src/Mlflow/mlflow_predict.py:45
#      42 mlflow_server_uri = "https://user-odione-mlflow.user.lab.sspcloud.fr"
#      44 mlflow_client = mlflow.tracking.MlflowClient()
# ---> 45 mlflow_client.download_artifacts(run_id=run_id, path="ct_data_transformers", dst_path=local_dir)
#      47 # Charger l'objet à partir du fichier téléchargé
#      48 artifact_path = os.path.join(local_dir, "ct_data_transformer.pkl")
#
# ...

# %%
https://datalab.sspcloud.fr/launcher/automation/mlflow?version=1.7.8&autoLaunch=true
