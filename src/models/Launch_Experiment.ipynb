# %%
import yaml

# Chemin vers le fichier YAML
yaml_file_path = "/chemin/vers/votre/fichier.yaml"

# Charger le contenu du fichier YAML
with open(yaml_file_path, "r") as yaml_file:
    mlf = yaml.safe_load(yaml_file)

# Accéder à la valeur spécifique
lien = mlf["spec"]["templates"][0]["container"]["args"][1].split("=")[1]

# Utiliser la valeur dans votre script
print(lien)
git push origin dev_models

# %%
import pandas as pd

# %%
lien="https://minio.lab.sspcloud.fr/alimane/diffusion/TMDB_movies.parquet"

# %%
{"code":3,"message":"templates.main.tasks.start-pipeline template 'start-pipeline-wt' type is unknown"}: templates.main.tasks.start-pipeline template 'start-pipeline-wt' type is unknown

# %%
{"code":3,"message":"templates.main.tasks.start-pipeline template 'start-pipeline-wt' type is unknown"}: templates.main.tasks.start-pipeline template 'start-pipeline-wt' type is unknown

# %%
- name: start-pipeline-wt
  dag:
    tasks:
      - name: echo-start-pipeline
        template: echo-start-pipeline

# %%
raw_data = pd.read_parquet(lien)[50:]
raw_data
# Out:
#               id                      title  vote_average  vote_count  \
# 50        297762               Wonder Woman         7.236       18954
# 51         14160                         Up         7.949       18857
# 52        102899                    Ant-Man         7.082       18730
# 53           238              The Godfather         8.707       18677
# 54        286217                The Martian         7.678       18525
# ...          ...                        ...           ...         ...
# 1032327   681663  The Best of Bosom Buddies         0.000           0
# 1032328   681664      Beautiful New Faces 3         0.000           0
# 1032329   681665  Cannibal Cheerleader Camp         0.000           0
# 1032330   681667      Beautiful New Faces 4         0.000           0
# 1032331  1284323         Karmika Kallanalla         0.000           0
#
#            status release_date    revenue  runtime  adult  \
# 50       Released   2017-05-30  822854286      141  False
# ...

# %%
models=train_models.XGBRegressorWrapper(raw_data,with_duration=False)
# Out:
# (x.shape, y.shape )
#
#  Pour le train : (8976, 29) (8976,)
#
#  Pour le test : (2395, 29) (2395,)
#
#  Pour la validation : (598, 29) (598,)

# %%
import src.models.train_Models_
# Out:
# (x.shape, y.shape )
#
#  Pour le train : (8976, 29) (8976,)
#
#  Pour le test : (2395, 29) (2395,)
#
#  Pour la validation : (598, 29) (598,)

# %%
train_models.tr
# Out:
# <module 'src.models.train_models' from '/home/onyxia/work/cine-insights/src/models/train_models.py'>

# %%
import src.Mlflow_src.mlflow_log as mlog

# %%
mlog.mlflow_fun(models,"Final_Experiment",2)
# Out:
# 2024/05/04 17:29:17 INFO mlflow.tracking.fluent: Experiment with name 'Final_Experiment' does not exist. Creating a new experiment.

# %%
import src.models.train_models
# Out:
# /home/onyxia/work/cine-insights/src/features/preprocess_train_data.py:892: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   .groupby(level=0, axis=1)
# /home/onyxia/work/cine-insights/src/features/preprocess_train_data.py:736: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)
# ...

# %%
import src.Mlflow_src.mlflow_Predict2
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# /home/onyxia/work/cine-insights/src/models/Launch_Experiment.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell://user-odione-952209-0.user.lab.sspcloud.fr/home/onyxia/work/cine-insights/src/models/Launch_Experiment.ipynb#X24sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> import src.Mlflow_src.mlflow_Predict2
#
# File ~/work/cine-insights/src/Mlflow_src/mlflow_Predict2.py:41
#      39 # Télécharger l'artefact depuis MLflow
#      40 mlflow_client = mlflow.tracking.MlflowClient()
# ---> 41 mlflow_client.download_artifacts(run_id=run_id, path="ct_data_transformers", dst_path=local_dir)
#      43 # Charger l'objet à partir du fichier téléchargé
#      44 artifact_path = os.path.join(local_dir, "ct_data_transformer.pkl")
#
# ...

# %%
src.Mlflow_src.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/onyxia/work/cine-insights/src/models/Launch_Experiment.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell://user-odione-952209-0.user.lab.sspcloud.fr/home/onyxia/work/cine-insights/src/models/Launch_Experiment.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> src.Mlflow_src.mlflow_Predict
#
# AttributeError: module 'src.Mlflow_src' has no attribute 'mlflow_Predict'

# %%
import src.models.train_models as train_models

# %%
models=train_models.XGBRegressorWrapper(restored_part,with_duration=False)
# Out:
# (x.shape, y.shape )
#
#  Pour le train : (9014, 29) (9014,)
#
#  Pour le test : (2404, 29) (2404,)
#
#  Pour la validation : (601, 29) (601,)
# /home/onyxia/work/cine-insights/src/features/preprocess_train_data.py:892: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   .groupby(level=0, axis=1)
# /home/onyxia/work/cine-insights/src/features/preprocess_train_data.py:736: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# ...

# %%
models=train_models.XGBRegressorWrapper(restored_part,with_duration=False)

# %%
models.best_params_
# Out:
# {}

# %%
models.param_Combination
# Out:
# [{'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 5,
#   'min_child_weight': 3,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 5,
#   'min_child_weight': 3,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 5,
#   'min_child_weight': 3,
#   'n_estimators': 500,
#   'objective': 'reg:squarederror',
#   'subsample': 0.9},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 5,
#   'min_child_weight': 3,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.7},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'max_depth': 5,
#   'min_child_weight': 3,
#   'n_estimators': 1000,
#   'objective': 'reg:squarederror',
#   'subsample': 0.8},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
# ...

# %%
import Mlflow_log4 as m

# %%
X=pd.read_csv("X.csv")

# %%
m.mlflow_fun(models,"Experiment1:sur tous les Donnees",1)

# %%
SessionTokenn="eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9.....7DBl9LN-hR7-E0dC2DOPOt_lhdnXVN7njX2CTMryfuoz0BOQIRXD8YbKEkG_icfog3H4VL0ixrur9xOKCDZwQg"

# %%
SecrteAcesskey="nXiQAN9P92QtG0DX2k5Xmy4+Shk3EQ"

# %%
AccesskeyId="AGM25ZG1Q0PK8PJV0FJS"

# %%
Endpoint="minio.lab.sspcloud.fr"

# %%
DefaultRegion="us-east-1"

# %%
import  Mlflow_log6b1
# Out:
# (x.shape, y.shape )
#
#  Pour le train : (9014, 29) (9014,)
#
#  Pour le test : (2404, 29) (2404,)
#
#  Pour la validation : (601, 29) (601,)

# %%
mlflow.ml

# %%
import src.models.maint4
# Out:
# (x.shape, y.shape )
#
#  Pour le train : (8976, 29) (8976,)
#
#  Pour le test : (2395, 29) (2395,)
#
#  Pour la validation : (598, 29) (598,)

# %%
import src.main
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/onyxia/work/cine-insights/src/models/Launch_Experiment.ipynb Cell 32 line 1
# ----> <a href='vscode-notebook-cell://user-odione-952209-0.user.lab.sspcloud.fr/home/onyxia/work/cine-insights/src/models/Launch_Experiment.ipynb#X43sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> import src.main
#
# File ~/work/cine-insights/src/main.py:16
#      14 import pandas as pd
#      15 import pickle
# ---> 16 import src.Mlflow_src.mlflow_log as mlog
#      17 import src.features.preprocess_train_data as preprocess_train_data
#      18 import src.features.preprocessing_predicted_data as preprocessing_predicted_data
#
# ModuleNotFoundError: No module named 'src.Mlflow_src'
